# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("2016-2022.csv", index_col="data_id")
df.head()
# Out:
#          iso event_id_cnty  event_id_no_cnty     event_date  year  \
# data_id
# 8912977  356     IND107923          107923.0  18 March 2022  2022
# 8912990  356     IND107846          107846.0  18 March 2022  2022
# 8913012  356     IND107941          107941.0  18 March 2022  2022
# 8913089  356     IND107842          107842.0  18 March 2022  2022
# 8913091  356     IND107850          107850.0  18 March 2022  2022
#
#          time_precision event_type    sub_event_type              actor1  \
# data_id
# 8912977               1      Riots      Mob violence     Rioters (India)
# 8912990               1   Protests  Peaceful protest  Protesters (India)
# 8913012               1   Protests  Peaceful protest  Protesters (India)
# 8913089               1   Protests  Peaceful protest  Protesters (India)
# 8913091               1      Riots      Mob violence     Rioters (India)
#
#                                              assoc_actor_1  inter1  \
# data_id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107690 entries, 8912977 to 8543376
# Data columns (total 30 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iso               107690 non-null  int64
#  1   event_id_cnty     107690 non-null  object
#  2   event_id_no_cnty  107690 non-null  float64
#  3   event_date        107690 non-null  object
#  4   year              107690 non-null  int64
#  5   time_precision    107690 non-null  int64
#  6   event_type        107690 non-null  object
#  7   sub_event_type    107690 non-null  object
#  8   actor1            107690 non-null  object
#  9   assoc_actor_1     76917 non-null   object
#  10  inter1            107690 non-null  int64
#  11  actor2            31375 non-null   object
#  12  assoc_actor_2     11511 non-null   object
#  13  inter2            107690 non-null  int64
#  14  interaction       107690 non-null  int64
#  15  region            107690 non-null  object
# ...

# %%
len(df)
# Out:
# 107690

# %%
#remove actor2 and assoc_actor_2
#consider using these columns as well (relation between actor 1 and actor 2)
df.drop(columns=["actor2", "assoc_actor_2"], inplace=True)

#fill null values on assoc_actor_1, admin2, admin3
df.fillna('Unknown', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107690 entries, 8912977 to 8543376
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   iso               107690 non-null  int64
#  1   event_id_cnty     107690 non-null  object
#  2   event_id_no_cnty  107690 non-null  float64
#  3   event_date        107690 non-null  object
#  4   year              107690 non-null  int64
#  5   time_precision    107690 non-null  int64
#  6   event_type        107690 non-null  object
#  7   sub_event_type    107690 non-null  object
#  8   actor1            107690 non-null  object
#  9   assoc_actor_1     107690 non-null  object
#  10  inter1            107690 non-null  int64
#  11  inter2            107690 non-null  int64
#  12  interaction       107690 non-null  int64
#  13  region            107690 non-null  object
#  14  country           107690 non-null  object
#  15  admin1            107690 non-null  object
# ...

# %%
df.head()
# Out:
#          iso event_id_cnty  event_id_no_cnty     event_date  year  \
# data_id
# 8912977  356     IND107923          107923.0  18 March 2022  2022
# 8912990  356     IND107846          107846.0  18 March 2022  2022
# 8913012  356     IND107941          107941.0  18 March 2022  2022
# 8913089  356     IND107842          107842.0  18 March 2022  2022
# 8913091  356     IND107850          107850.0  18 March 2022  2022
#
#          time_precision event_type    sub_event_type              actor1  \
# data_id
# 8912977               1      Riots      Mob violence     Rioters (India)
# 8912990               1   Protests  Peaceful protest  Protesters (India)
# 8913012               1   Protests  Peaceful protest  Protesters (India)
# 8913089               1   Protests  Peaceful protest  Protesters (India)
# 8913091               1      Riots      Mob violence     Rioters (India)
#
#                                              assoc_actor_1  inter1  inter2  \
# data_id
# ...
